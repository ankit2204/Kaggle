# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.shape
# Out:
# (891, 12)

# %%
groups = data.groupby('Pclass','')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-0e74a4b75f04> in <module>()
# ----> 1 groups = data.groupby('Pclass','')
#
# /Users/ankit2204/venv/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5157         if level is None and by is None:
#    5158             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 5159         axis = self._get_axis_number(axis)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
#
# /Users/ankit2204/venv/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_axis_number(self, axis)
#     355                 pass
#     356         raise ValueError('No axis named {0} for object type {1}'
# ...

# %%
groups.groups
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ba4ca1e8b39f> in <module>()
# ----> 1 groups.groups
#
# NameError: name 'groups' is not defined

# %%
print groups['Pclass'].agg(np.sum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-1824fc7ccaf3> in <module>()
# ----> 1 print groups['Pclass'].agg(np.sum)
#
# NameError: name 'groups' is not defined

# %%
print groups['Survived'].agg(np.sum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-de6705c309b2> in <module>()
# ----> 1 print groups['Survived'].agg(np.sum)
#
# NameError: name 'groups' is not defined

# %%
data['Age'].mean()
# Out:
# 29.69911764705882

# %%
data.loc[data['Age'].isnull(),'Age'] = int(data['Age'].mean())

# %%
data['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5      29.0
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17     29.0
# 18     31.0
# 19     29.0
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26     29.0
# 27     19.0
# 28     29.0
# 29     29.0
#        ...
# 861    21.0
# 862    48.0
# 863    29.0
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868    29.0
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878    29.0
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888    29.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data.groupby('Survived').mean()
# Out:
#           PassengerId    Pclass       Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.25592  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.44348  0.473684  0.464912  48.395408

# %%
data['S'] = np.where(data['Sex']=='male',1,0)

# %%
data['is_female'] = np.where(data['Sex']=='female',1,0)

# %%
data.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Name', u'Sex', u'Age',
#        u'SibSp', u'Parch', u'Ticket', u'Fare', u'Cabin', u'Embarked', u'S',
#        u'is_female'],
#       dtype='object')

# %%
data.drop(['is_female'],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
data = data.drop(['is_male'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-ae2c40524666> in <module>()
# ----> 1 data = data.drop(['is_male'],axis=1)
#
# /Users/ankit2204/venv/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# /Users/ankit2204/venv/lib/python2.7/site-packages/pandas/core/generic.pyc in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
# ...

# %%
data = data.drop(['is_female'],axis=1)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  S
# 0      0         A/5 21171   7.2500   NaN        S  1
# 1      0          PC 17599  71.2833   C85        C  0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  0
# 3      0            113803  53.1000  C123        S  0
# ...

# %%
data_class = pd.get_dummies(data['Pclass'])

# %%
data_class.columns = ['Pclass_1','Pclass_2','Pclass_3']

# %%
data_class.head()
# Out:
#    Pclass_1  Pclass_2  Pclass_3
# 0         0         0         1
# 1         1         0         0
# 2         0         0         1
# 3         1         0         0
# 4         0         0         1

# %%
data = pd.concat([data,data_class],axis=1)

# %%
data[data['SibSp']>0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 7              8         0       3
# 9             10         1       2
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# 18            19         0       3
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 35            36         0       1
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 46            47         0       3
# 48            49         0       3
# 49            50         0       3
# 50            51         0       3
# 52            53         1       1
# ...

# %%
data['is_alone'] = np.where((data['SibSp']==0) & (data['Parch']==0),1,0)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  S  Pclass_1  Pclass_2  \
# 0      0         A/5 21171   7.2500   NaN        S  1         0         0
# 1      0          PC 17599  71.2833   C85        C  0         1         0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  0         0         0
# ...

# %%
data['Gender'] = np.where(data['Sex']=='male',1,0)

# %%
data = data.drop('Pclass_3',axis=1)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  S  Pclass_1  Pclass_2  \
# 0      0         A/5 21171   7.2500   NaN        S  1         0         0
# 1      0          PC 17599  71.2833   C85        C  0         1         0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  0         0         0
# ...

# %%
logreg = LogisticRegression()

# %%
data.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
X_train = data.loc[:,['Age','is_alone','Gender','Pclass_1','Pclass_2']]

# %%
X_train.head()
# Out:
#     Age  is_alone  Gender  Pclass_1  Pclass_2
# 0  22.0         0       1         0         0
# 1  38.0         0       0         1         0
# 2  26.0         1       0         0         0
# 3  35.0         0       0         1         0
# 4  35.0         1       1         0         0

# %%
y_train = data['Survived']

# %%
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
data_test = pd.read_csv('test.csv')

# %%
data_test.shape
# Out:
# (418, 11)

# %%
data_test.loc[data_test['Age'].isnull(),'Age'] = int(data_test['Age'].mean())

# %%
data_test['is_alone'] = np.where((data_test['SibSp']==0) & (data_test['Parch']==0),1,0)

# %%
data_test['Gender'] = np.where(data_test['Sex']=='male',1,0)

# %%
data_class = pd.get_dummies(data_test['Pclass'])

# %%
data_class.columns = ['Pclass_1','Pclass_2','Pclass_3']

# %%
data_test = pd.concat([data_test,data_class],axis=1)

# %%
data_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  is_alone  Gender  \
# 0  34.5      0      0   330911   7.8292   NaN        Q         1       1
# 1  47.0      1      0   363272   7.0000   NaN        S         0       0
# 2  62.0      0      0   240276   9.6875   NaN        Q         1       1
# 3  27.0      0      0   315154   8.6625   NaN        S         1       1
# 4  22.0      1      1  3101298  12.2875   NaN        S         0       0
#
#    Pclass_1  Pclass_2  Pclass_3
# ...

# %%
X_test = data_test.loc[:,['Age','is_alone','Gender','Pclass_1','Pclass_2']]

# %%
y_pred = logreg.predict(X_test)

# %%
results = data_test['PassengerId']

# %%
results.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-164-00a530f8548d> in <module>()
# ----> 1 results.columns
#
# /Users/ankit2204/venv/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3608         if (name in self._internal_names_set or name in self._metadata or
#    3609                 name in self._accessors):
# -> 3610             return object.__getattribute__(self, name)
#    3611         else:
#    3612             if name in self._info_axis:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
x = pd.Series(y_pred)

# %%
results = pd.DataFrame(data=results.values, columns=['PassengerId'])

# %%
results.head()
# Out:
#    PassengerId
# 0          892
# 1          893
# 2          894
# 3          895
# 4          896

# %%
results['Survived'] = x

# %%
results.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
results.to_csv('prediction.csv',index = False)

# %%
print('coefficient:', logreg.coef_[0])
# Out:
# ('coefficient:', array([-0.03014188,  0.04018929, -2.48989283,  2.15947117,  1.11126457]))
